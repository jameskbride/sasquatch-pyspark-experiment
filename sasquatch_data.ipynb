# %%
from pyspark import SparkContext
from pyspark.sql import SparkSession
# spark is from the previous example.
spark = SparkSession \
    .builder \
    .appName("Simple") \
    .getOrCreate()
sc = spark.sparkContext
# A JSON dataset is pointed to by path.
# The path can be either a single text file or a directory storing text files

def build_json_dataframe(path):
    lines = spark.read.json(path)
    return lines
    
incidents_json = build_json_dataframe("/usr/local/data/sasquatch/sasquatch_incident_bulk.json")
creature_json = build_json_dataframe("/usr/local/data/sasquatch/sasquatch_creature_bulk.json")
footprint_json = build_json_dataframe("/usr/local/data/sasquatch/sasquatch_footprint_bulk.json")
witness_json = build_json_dataframe("/usr/local/data/sasquatch/sasquatch_witness_bulk.json")

# %%
incidents_json.printSchema()
# Out:
# root
#  |-- i_account_of_incident: string (nullable = true)
#  |-- i_cast_made: string (nullable = true)
#  |-- i_clarity: string (nullable = true)
#  |-- i_condition: string (nullable = true)
#  |-- i_county: string (nullable = true)
#  |-- i_creature_id: string (nullable = true)
#  |-- i_dead: string (nullable = true)
#  |-- i_died: string (nullable = true)
#  |-- i_direction_from_town: string (nullable = true)
#  |-- i_distance_from_town: double (nullable = true)
#  |-- i_distance_to_water: string (nullable = true)
#  |-- i_duration: string (nullable = true)
#  |-- i_effect_of_shot: string (nullable = true)
#  |-- i_elevation: double (nullable = true)
#  |-- i_entry_date: string (nullable = true)
#  |-- i_exact_terrain: string (nullable = true)
#  |-- i_exact_trees: string (nullable = true)
#  |-- i_exact_undergrowth: string (nullable = true)
#  |-- i_first_seen: string (nullable = true)
#  |-- i_footprint_id: string (nullable = true)
#  |-- i_humidity: string (nullable = true)
#  |-- i_incident_id: long (nullable = true)
#  |-- i_incident_one_of_a_series: string (nullable = true)
#  |-- i_incident_reliablility: long (nullable = true)
#  |-- i_incident_type: string (nullable = true)
#  |-- i_jwg_file_date: string (nullable = true)
#  |-- i_latitude: string (nullable = true)
#  |-- i_lighting: string (nullable = true)
#  |-- i_longitude: string (nullable = true)
#  |-- i_month: string (nullable = true)
#  |-- i_more_incident_codes_y_n: string (nullable = true)
#  |-- i_more_info_needed: string (nullable = true)
#  |-- i_name: string (nullable = true)
#  |-- i_near: string (nullable = true)
#  |-- i_nearby_water: string (nullable = true)
#  |-- i_nearest_town: string (nullable = true)
#  |-- i_no_of_individuals: string (nullable = true)
#  |-- i_no_of_witnesses: string (nullable = true)
#  |-- i_observation_date: string (nullable = true)
#  |-- i_observation_day: string (nullable = true)
#  |-- i_operator: string (nullable = true)
#  |-- i_photo: string (nullable = true)
#  |-- i_pop_status: string (nullable = true)
#  |-- i_population_of_town: long (nullable = true)
#  |-- i_related_incident_id: string (nullable = true)
#  |-- i_season: string (nullable = true)
#  |-- i_shot_hit: string (nullable = true)
#  |-- i_slope: string (nullable = true)
#  |-- i_slope_faced: string (nullable = true)
#  |-- i_snow: string (nullable = true)
#  |-- i_snow_condition: string (nullable = true)
#  |-- i_source_date: string (nullable = true)
#  |-- i_source_reliability: long (nullable = true)
#  |-- i_source_type: string (nullable = true)
#  |-- i_species: string (nullable = true)
#  |-- i_state_prov: string (nullable = true)
#  |-- i_substratum: string (nullable = true)
#  |-- i_superhuman_action: string (nullable = true)
#  |-- i_terrain: string (nullable = true)
#  |-- i_terrain_object: string (nullable = true)
#  |-- i_time_of_day: string (nullable = true)
#  |-- i_total: string (nullable = true)
#  |-- i_track_photo_y_n: string (nullable = true)
#  |-- i_track_witnesses: string (nullable = true)
#  |-- i_tracks: string (nullable = true)
#  |-- i_tree_condition: string (nullable = true)
#  |-- i_tree_cover: string (nullable = true)
#  |-- i_tree_size: string (nullable = true)
#  |-- i_tree_type: string (nullable = true)
#  |-- i_trees_unnatural: string (nullable = true)
#  |-- i_type: string (nullable = true)
#  |-- i_undergrowth: string (nullable = true)
#  |-- i_undergrowth_size: string (nullable = true)
#  |-- i_undergrowth_type: string (nullable = true)
#  |-- i_unnatural_undergrowth: string (nullable = true)
#  |-- i_variety: string (nullable = true)
#  |-- i_visibility_index: long (nullable = true)
#  |-- i_weather_heat: string (nullable = true)
#  |-- i_wetness: string (nullable = true)
#  |-- i_wind: string (nullable = true)
#  |-- i_witness_id: string (nullable = true)
#  |-- i_witness_sex: string (nullable = true)
#  |-- i_year: string (nullable = true)

# %%
creature_json.printSchema()
# Out:
# root
#  |-- c_abdomen: string (nullable = true)
#  |-- c_aggressive_to: string (nullable = true)
#  |-- c_animal_present: string (nullable = true)
#  |-- c_arm_bulk: string (nullable = true)
#  |-- c_arms: string (nullable = true)
#  |-- c_arms_action: string (nullable = true)
#  |-- c_arms_used: string (nullable = true)
#  |-- c_at_speed: string (nullable = true)
#  |-- c_attracted_by: string (nullable = true)
#  |-- c_back_of_head: string (nullable = true)
#  |-- c_beard: string (nullable = true)
#  |-- c_breasts: string (nullable = true)
#  |-- c_broken_ice: string (nullable = true)
#  |-- c_brow_ridge: string (nullable = true)
#  |-- c_build: string (nullable = true)
#  |-- c_buttocks: string (nullable = true)
#  |-- c_captured: string (nullable = true)
#  |-- c_chin: string (nullable = true)
#  |-- c_comp_entry_date: string (nullable = true)
#  |-- c_covered_with_hair: string (nullable = true)
#  |-- c_creature_ID: long (nullable = true)
#  |-- c_creature_c: string (nullable = true)
#  |-- c_death: string (nullable = true)
#  |-- c_decribe_unusual: string (nullable = true)
#  |-- c_detailed_report: string (nullable = true)
#  |-- c_different_color: string (nullable = true)
#  |-- c_digits: string (nullable = true)
#  |-- c_ear_size: string (nullable = true)
#  |-- c_ears: string (nullable = true)
#  |-- c_eating: string (nullable = true)
#  |-- c_elim_where: string (nullable = true)
#  |-- c_elimination: string (nullable = true)
#  |-- c_est_speed: string (nullable = true)
#  |-- c_evidence: string (nullable = true)
#  |-- c_evidence_left: string (nullable = true)
#  |-- c_eye_color: string (nullable = true)
#  |-- c_eye_human: string (nullable = true)
#  |-- c_eye_shape: string (nullable = true)
#  |-- c_eye_spacing: string (nullable = true)
#  |-- c_eyes: string (nullable = true)
#  |-- c_face_appeared: string (nullable = true)
#  |-- c_face_color: string (nullable = true)
#  |-- c_face_expression: string (nullable = true)
#  |-- c_feet: string (nullable = true)
#  |-- c_feet_color: string (nullable = true)
#  |-- c_fingernails: string (nullable = true)
#  |-- c_foot_width: string (nullable = true)
#  |-- c_forehead: string (nullable = true)
#  |-- c_forehead_shape: string (nullable = true)
#  |-- c_genitals: string (nullable = true)
#  |-- c_hair_appearance: string (nullable = true)
#  |-- c_hair_color: string (nullable = true)
#  |-- c_hair_covered: string (nullable = true)
#  |-- c_hair_curl: string (nullable = true)
#  |-- c_hair_length: string (nullable = true)
#  |-- c_hair_longer_on: string (nullable = true)
#  |-- c_hair_shorter_on: string (nullable = true)
#  |-- c_hair_thin: string (nullable = true)
#  |-- c_hair_tone: string (nullable = true)
#  |-- c_hands: string (nullable = true)
#  |-- c_hands_color: string (nullable = true)
#  |-- c_head_profile: string (nullable = true)
#  |-- c_head_size: string (nullable = true)
#  |-- c_heel: string (nullable = true)
#  |-- c_height: string (nullable = true)
#  |-- c_human_contact: string (nullable = true)
#  |-- c_human_hands: string (nullable = true)
#  |-- c_incident_ID: string (nullable = true)
#  |-- c_knees: string (nullable = true)
#  |-- c_leg_width: string (nullable = true)
#  |-- c_legs: string (nullable = true)
#  |-- c_lips: string (nullable = true)
#  |-- c_mouth_open: string (nullable = true)
#  |-- c_mouth_s: string (nullable = true)
#  |-- c_mouth_size: string (nullable = true)
#  |-- c_movement_direct: string (nullable = true)
#  |-- c_movement_first: string (nullable = true)
#  |-- c_movement_later: string (nullable = true)
#  |-- c_movement_was: string (nullable = true)
#  |-- c_neck_length: string (nullable = true)
#  |-- c_neck_width: string (nullable = true)
#  |-- c_no_hair: string (nullable = true)
#  |-- c_no_hair_on: string (nullable = true)
#  |-- c_nose: string (nullable = true)
#  |-- c_nose_shape: string (nullable = true)
#  |-- c_nostrils: string (nullable = true)
#  |-- c_object_handled: string (nullable = true)
#  |-- c_odour: string (nullable = true)
#  |-- c_operator: string (nullable = true)
#  |-- c_other_activity: string (nullable = true)
#  |-- c_other_color: string (nullable = true)
#  |-- c_other_unusual: string (nullable = true)
#  |-- c_pos_first_seen: string (nullable = true)
#  |-- c_posture: string (nullable = true)
#  |-- c_projecting_jaw: string (nullable = true)
#  |-- c_reaction: string (nullable = true)
#  |-- c_reflection: string (nullable = true)
#  |-- c_running_speed: string (nullable = true)
#  |-- c_running_steps: string (nullable = true)
#  |-- c_second_color: string (nullable = true)
#  |-- c_second_hair_color: string (nullable = true)
#  |-- c_shoulders: string (nullable = true)
#  |-- c_shoulders_shape: string (nullable = true)
#  |-- c_sound: string (nullable = true)
#  |-- c_speed: string (nullable = true)
#  |-- c_spine: string (nullable = true)
#  |-- c_state_prov: string (nullable = true)
#  |-- c_tail: string (nullable = true)
#  |-- c_teeth: string (nullable = true)
#  |-- c_then: string (nullable = true)
#  |-- c_then_creature: string (nullable = true)
#  |-- c_third_color: string (nullable = true)
#  |-- c_thumb: string (nullable = true)
#  |-- c_toe_shape: string (nullable = true)
#  |-- c_toenails: string (nullable = true)
#  |-- c_toenails_color: string (nullable = true)
#  |-- c_toes: string (nullable = true)
#  |-- c_torso_front: string (nullable = true)
#  |-- c_torso_shape: string (nullable = true)
#  |-- c_torso_side: string (nullable = true)
#  |-- c_use_of_water: string (nullable = true)
#  |-- c_walking_speed: string (nullable = true)
#  |-- c_walking_steps: string (nullable = true)
#  |-- c_water_activity: string (nullable = true)
#  |-- c_water_depth: string (nullable = true)
#  |-- c_way_of_walking: string (nullable = true)

# %%
footprint_json.printSchema()
# Out:
# root
#  |-- f_age_unit: string (nullable = true)
#  |-- f_animal_weight: long (nullable = true)
#  |-- f_arch: string (nullable = true)
#  |-- f_average: string (nullable = true)
#  |-- f_average_stride: string (nullable = true)
#  |-- f_ball: double (nullable = true)
#  |-- f_ball_of_foot: string (nullable = true)
#  |-- f_bumps: string (nullable = true)
#  |-- f_cast: string (nullable = true)
#  |-- f_claw_marks: string (nullable = true)
#  |-- f_comp_entry_date: string (nullable = true)
#  |-- f_condition: string (nullable = true)
#  |-- f_deformity: string (nullable = true)
#  |-- f_direction: string (nullable = true)
#  |-- f_estimated_age: string (nullable = true)
#  |-- f_feet_in_line: string (nullable = true)
#  |-- f_foot_shape: string (nullable = true)
#  |-- f_footprint_ID: long (nullable = true)
#  |-- f_greates_width: string (nullable = true)
#  |-- f_hand_print_s: string (nullable = true)
#  |-- f_heel: string (nullable = true)
#  |-- f_heel_width: string (nullable = true)
#  |-- f_human: string (nullable = true)
#  |-- f_human_tracks_present: string (nullable = true)
#  |-- f_incident_ID: string (nullable = true)
#  |-- f_knee_prints: string (nullable = true)
#  |-- f_length: string (nullable = true)
#  |-- f_longest_stride: long (nullable = true)
#  |-- f_longest_toe: string (nullable = true)
#  |-- f_material_made_in: string (nullable = true)
#  |-- f_number_of_toes: long (nullable = true)
#  |-- f_number_of_tracks: string (nullable = true)
#  |-- f_obs_print: double (nullable = true)
#  |-- f_obs_weight: long (nullable = true)
#  |-- f_obstacles: string (nullable = true)
#  |-- f_operation: string (nullable = true)
#  |-- f_other_footprint_codes: string (nullable = true)
#  |-- f_other_marks: string (nullable = true)
#  |-- f_other_tracks: string (nullable = true)
#  |-- f_pattern_of_walk: string (nullable = true)
#  |-- f_photo: string (nullable = true)
#  |-- f_remarks: string (nullable = true)
#  |-- f_ridge: string (nullable = true)
#  |-- f_set_of_tracks: long (nullable = true)
#  |-- f_shortest_stride: long (nullable = true)
#  |-- f_size_of_toes: string (nullable = true)
#  |-- f_state_prov: string (nullable = true)
#  |-- f_stride_inches: string (nullable = true)
#  |-- f_toes: double (nullable = true)
#  |-- f_trackmaker_attracted_by: string (nullable = true)
#  |-- f_tracks_came_from: string (nullable = true)
#  |-- f_tracks_showed: string (nullable = true)
#  |-- f_trail_ended: string (nullable = true)
#  |-- f_trail_followed: string (nullable = true)
#  |-- f_water: string (nullable = true)
#  |-- f_went_to: string (nullable = true)
#  |-- f_what: string (nullable = true)

# %%
witness_json.printSchema()
# Out:
# root
#  |-- w_action_at_sight: string (nullable = true)
#  |-- w_approx_age: string (nullable = true)
#  |-- w_city: string (nullable = true)
#  |-- w_comp_entry_date: string (nullable = true)
#  |-- w_confidential: string (nullable = true)
#  |-- w_date_of_birth: string (nullable = true)
#  |-- w_first_name: string (nullable = true)
#  |-- w_incident_id: string (nullable = true)
#  |-- w_index: string (nullable = true)
#  |-- w_interview_Date: string (nullable = true)
#  |-- w_interviewer: string (nullable = true)
#  |-- w_least_horiz_distance: string (nullable = true)
#  |-- w_least_vert_distance: string (nullable = true)
#  |-- w_middle_name: string (nullable = true)
#  |-- w_most_horiz_distance: string (nullable = true)
#  |-- w_most_vert_distance: string (nullable = true)
#  |-- w_moving: string (nullable = true)
#  |-- w_multi_report: string (nullable = true)
#  |-- w_net: string (nullable = true)
#  |-- w_no_of_witnesses: string (nullable = true)
#  |-- w_notes: string (nullable = true)
#  |-- w_observer_noise: string (nullable = true)
#  |-- w_observer_was: string (nullable = true)
#  |-- w_occupation: string (nullable = true)
#  |-- w_operator: string (nullable = true)
#  |-- w_phone: string (nullable = true)
#  |-- w_photo_y_n: string (nullable = true)
#  |-- w_position: string (nullable = true)
#  |-- w_post_code: string (nullable = true)
#  |-- w_saw_with: string (nullable = true)
#  |-- w_schooling: string (nullable = true)
#  |-- w_sex: string (nullable = true)
#  |-- w_shot_hit: string (nullable = true)
#  |-- w_state: string (nullable = true)
#  |-- w_state_prov: string (nullable = true)
#  |-- w_street: string (nullable = true)
#  |-- w_surname: string (nullable = true)
#  |-- w_tape_or_video: string (nullable = true)
#  |-- w_track_witnesses: string (nullable = true)
#  |-- w_tracks: string (nullable = true)
#  |-- w_wildlife_fam: string (nullable = true)
#  |-- w_witness_id: long (nullable = true)

# %%
incidents_witnesses = incidents_json.join(witness_json, incidents_json.i_incident_id == witness_json.w_incident_id, 'inner')
incidents_witnesses_columns = ['i_incident_id', 'w_action_at_sight', 'w_approx_age', 'w_city', 'w_comp_entry_date', 'w_confidential', 'w_date_of_birth', 'w_first_name', 'w_incident_id', 'w_index', 'w_interview_Date', 'w_interviewer', 'w_least_horiz_distance', 'w_least_vert_distance', 'w_middle_name', 'w_most_horiz_distance', 'w_most_vert_distance', 'w_moving', 'w_multi_report', 'w_net', 'w_no_of_witnesses', 'w_notes', 'w_observer_noise', 'w_observer_was', 'w_occupation', 'w_operator', 'w_phone', 'w_photo_y_n', 'w_position', 'w_post_code', 'w_saw_with', 'w_schooling', 'w_sex', 'w_shot_hit', 'w_state', 'w_state_prov', 'w_street', 'w_surname', 'w_tape_or_video', 'w_track_witnesses', 'w_tracks', 'w_wildlife_fam', 'w_witness_id']
print(witness_json.columns)
incidents_witnesses = incidents_witnesses.select(incidents_witnesses_columns).withColumnRenamed('i_incident_id', 'iw_incident_id')
incidents_witnesses.printSchema()
# Out:
# ['w_action_at_sight', 'w_approx_age', 'w_city', 'w_comp_entry_date', 'w_confidential', 'w_date_of_birth', 'w_first_name', 'w_incident_id', 'w_index', 'w_interview_Date', 'w_interviewer', 'w_least_horiz_distance', 'w_least_vert_distance', 'w_middle_name', 'w_most_horiz_distance', 'w_most_vert_distance', 'w_moving', 'w_multi_report', 'w_net', 'w_no_of_witnesses', 'w_notes', 'w_observer_noise', 'w_observer_was', 'w_occupation', 'w_operator', 'w_phone', 'w_photo_y_n', 'w_position', 'w_post_code', 'w_saw_with', 'w_schooling', 'w_sex', 'w_shot_hit', 'w_state', 'w_state_prov', 'w_street', 'w_surname', 'w_tape_or_video', 'w_track_witnesses', 'w_tracks', 'w_wildlife_fam', 'w_witness_id']
# root
#  |-- iw_incident_id: long (nullable = true)
#  |-- w_action_at_sight: string (nullable = true)
#  |-- w_approx_age: string (nullable = true)
#  |-- w_city: string (nullable = true)
#  |-- w_comp_entry_date: string (nullable = true)
#  |-- w_confidential: string (nullable = true)
#  |-- w_date_of_birth: string (nullable = true)
#  |-- w_first_name: string (nullable = true)
#  |-- w_incident_id: string (nullable = true)
#  |-- w_index: string (nullable = true)
#  |-- w_interview_Date: string (nullable = true)
#  |-- w_interviewer: string (nullable = true)
#  |-- w_least_horiz_distance: string (nullable = true)
#  |-- w_least_vert_distance: string (nullable = true)
#  |-- w_middle_name: string (nullable = true)
#  |-- w_most_horiz_distance: string (nullable = true)
#  |-- w_most_vert_distance: string (nullable = true)
#  |-- w_moving: string (nullable = true)
#  |-- w_multi_report: string (nullable = true)
#  |-- w_net: string (nullable = true)
#  |-- w_no_of_witnesses: string (nullable = true)
#  |-- w_notes: string (nullable = true)
#  |-- w_observer_noise: string (nullable = true)
#  |-- w_observer_was: string (nullable = true)
#  |-- w_occupation: string (nullable = true)
#  |-- w_operator: string (nullable = true)
#  |-- w_phone: string (nullable = true)
#  |-- w_photo_y_n: string (nullable = true)
#  |-- w_position: string (nullable = true)
#  |-- w_post_code: string (nullable = true)
#  |-- w_saw_with: string (nullable = true)
#  |-- w_schooling: string (nullable = true)
#  |-- w_sex: string (nullable = true)
#  |-- w_shot_hit: string (nullable = true)
#  |-- w_state: string (nullable = true)
#  |-- w_state_prov: string (nullable = true)
#  |-- w_street: string (nullable = true)
#  |-- w_surname: string (nullable = true)
#  |-- w_tape_or_video: string (nullable = true)
#  |-- w_track_witnesses: string (nullable = true)
#  |-- w_tracks: string (nullable = true)
#  |-- w_wildlife_fam: string (nullable = true)
#  |-- w_witness_id: long (nullable = true)

# %%
print(creature_json.columns)
# incidents_creatures = incidents_json.join(creature_json, incidents_json.i_incident_id == creature_json.c_incident_ID, 'inner')
incidents_creatures = incidents_json.join(creature_json, incidents_json.i_incident_id == creature_json.c_incident_ID, 'inner')
incidents_creatures_columns = ['i_incident_id', 'c_abdomen', 'c_aggressive_to', 'c_animal_present', 'c_arm_bulk', 'c_arms', 'c_arms_action', 'c_arms_used', 'c_at_speed', 'c_attracted_by', 'c_back_of_head', 'c_beard', 'c_breasts', 'c_broken_ice', 'c_brow_ridge', 'c_build', 'c_buttocks', 'c_captured', 'c_chin', 'c_comp_entry_date', 'c_covered_with_hair', 'c_creature_ID', 'c_creature_c', 'c_death', 'c_decribe_unusual', 'c_detailed_report', 'c_different_color', 'c_digits', 'c_ear_size', 'c_ears', 'c_eating', 'c_elim_where', 'c_elimination', 'c_est_speed', 'c_evidence', 'c_evidence_left', 'c_eye_color', 'c_eye_human', 'c_eye_shape', 'c_eye_spacing', 'c_eyes', 'c_face_appeared', 'c_face_color', 'c_face_expression', 'c_feet', 'c_feet_color', 'c_fingernails', 'c_foot_width', 'c_forehead', 'c_forehead_shape', 'c_genitals', 'c_hair_appearance', 'c_hair_color', 'c_hair_covered', 'c_hair_curl', 'c_hair_length', 'c_hair_longer_on', 'c_hair_shorter_on', 'c_hair_thin', 'c_hair_tone', 'c_hands', 'c_hands_color', 'c_head_profile', 'c_head_size', 'c_heel', 'c_height', 'c_human_contact', 'c_human_hands', 'c_incident_ID', 'c_knees', 'c_leg_width', 'c_legs', 'c_lips', 'c_mouth_open', 'c_mouth_s', 'c_mouth_size', 'c_movement_direct', 'c_movement_first', 'c_movement_later', 'c_movement_was', 'c_neck_length', 'c_neck_width', 'c_no_hair', 'c_no_hair_on', 'c_nose', 'c_nose_shape', 'c_nostrils', 'c_object_handled', 'c_odour', 'c_operator', 'c_other_activity', 'c_other_color', 'c_other_unusual', 'c_pos_first_seen', 'c_posture', 'c_projecting_jaw', 'c_reaction', 'c_reflection', 'c_running_speed', 'c_running_steps', 'c_second_color', 'c_second_hair_color', 'c_shoulders', 'c_shoulders_shape', 'c_sound', 'c_speed', 'c_spine', 'c_state_prov', 'c_tail', 'c_teeth', 'c_then', 'c_then_creature', 'c_third_color', 'c_thumb', 'c_toe_shape', 'c_toenails', 'c_toenails_color', 'c_toes', 'c_torso_front', 'c_torso_shape', 'c_torso_side', 'c_use_of_water', 'c_walking_speed', 'c_walking_steps', 'c_water_activity', 'c_water_depth', 'c_way_of_walking']
incidents_creatures = incidents_creatures.select(incidents_creatures_columns).withColumnRenamed('i_incident_id', 'ic_incident_id')
incidents_creatures.printSchema()
# Out:
# ['c_abdomen', 'c_aggressive_to', 'c_animal_present', 'c_arm_bulk', 'c_arms', 'c_arms_action', 'c_arms_used', 'c_at_speed', 'c_attracted_by', 'c_back_of_head', 'c_beard', 'c_breasts', 'c_broken_ice', 'c_brow_ridge', 'c_build', 'c_buttocks', 'c_captured', 'c_chin', 'c_comp_entry_date', 'c_covered_with_hair', 'c_creature_ID', 'c_creature_c', 'c_death', 'c_decribe_unusual', 'c_detailed_report', 'c_different_color', 'c_digits', 'c_ear_size', 'c_ears', 'c_eating', 'c_elim_where', 'c_elimination', 'c_est_speed', 'c_evidence', 'c_evidence_left', 'c_eye_color', 'c_eye_human', 'c_eye_shape', 'c_eye_spacing', 'c_eyes', 'c_face_appeared', 'c_face_color', 'c_face_expression', 'c_feet', 'c_feet_color', 'c_fingernails', 'c_foot_width', 'c_forehead', 'c_forehead_shape', 'c_genitals', 'c_hair_appearance', 'c_hair_color', 'c_hair_covered', 'c_hair_curl', 'c_hair_length', 'c_hair_longer_on', 'c_hair_shorter_on', 'c_hair_thin', 'c_hair_tone', 'c_hands', 'c_hands_color', 'c_head_profile', 'c_head_size', 'c_heel', 'c_height', 'c_human_contact', 'c_human_hands', 'c_incident_ID', 'c_knees', 'c_leg_width', 'c_legs', 'c_lips', 'c_mouth_open', 'c_mouth_s', 'c_mouth_size', 'c_movement_direct', 'c_movement_first', 'c_movement_later', 'c_movement_was', 'c_neck_length', 'c_neck_width', 'c_no_hair', 'c_no_hair_on', 'c_nose', 'c_nose_shape', 'c_nostrils', 'c_object_handled', 'c_odour', 'c_operator', 'c_other_activity', 'c_other_color', 'c_other_unusual', 'c_pos_first_seen', 'c_posture', 'c_projecting_jaw', 'c_reaction', 'c_reflection', 'c_running_speed', 'c_running_steps', 'c_second_color', 'c_second_hair_color', 'c_shoulders', 'c_shoulders_shape', 'c_sound', 'c_speed', 'c_spine', 'c_state_prov', 'c_tail', 'c_teeth', 'c_then', 'c_then_creature', 'c_third_color', 'c_thumb', 'c_toe_shape', 'c_toenails', 'c_toenails_color', 'c_toes', 'c_torso_front', 'c_torso_shape', 'c_torso_side', 'c_use_of_water', 'c_walking_speed', 'c_walking_steps', 'c_water_activity', 'c_water_depth', 'c_way_of_walking']
# root
#  |-- ic_incident_id: long (nullable = true)
#  |-- c_abdomen: string (nullable = true)
#  |-- c_aggressive_to: string (nullable = true)
#  |-- c_animal_present: string (nullable = true)
#  |-- c_arm_bulk: string (nullable = true)
#  |-- c_arms: string (nullable = true)
#  |-- c_arms_action: string (nullable = true)
#  |-- c_arms_used: string (nullable = true)
#  |-- c_at_speed: string (nullable = true)
#  |-- c_attracted_by: string (nullable = true)
#  |-- c_back_of_head: string (nullable = true)
#  |-- c_beard: string (nullable = true)
#  |-- c_breasts: string (nullable = true)
#  |-- c_broken_ice: string (nullable = true)
#  |-- c_brow_ridge: string (nullable = true)
#  |-- c_build: string (nullable = true)
#  |-- c_buttocks: string (nullable = true)
#  |-- c_captured: string (nullable = true)
#  |-- c_chin: string (nullable = true)
#  |-- c_comp_entry_date: string (nullable = true)
#  |-- c_covered_with_hair: string (nullable = true)
#  |-- c_creature_ID: long (nullable = true)
#  |-- c_creature_c: string (nullable = true)
#  |-- c_death: string (nullable = true)
#  |-- c_decribe_unusual: string (nullable = true)
#  |-- c_detailed_report: string (nullable = true)
#  |-- c_different_color: string (nullable = true)
#  |-- c_digits: string (nullable = true)
#  |-- c_ear_size: string (nullable = true)
#  |-- c_ears: string (nullable = true)
#  |-- c_eating: string (nullable = true)
#  |-- c_elim_where: string (nullable = true)
#  |-- c_elimination: string (nullable = true)
#  |-- c_est_speed: string (nullable = true)
#  |-- c_evidence: string (nullable = true)
#  |-- c_evidence_left: string (nullable = true)
#  |-- c_eye_color: string (nullable = true)
#  |-- c_eye_human: string (nullable = true)
#  |-- c_eye_shape: string (nullable = true)
#  |-- c_eye_spacing: string (nullable = true)
#  |-- c_eyes: string (nullable = true)
#  |-- c_face_appeared: string (nullable = true)
#  |-- c_face_color: string (nullable = true)
#  |-- c_face_expression: string (nullable = true)
#  |-- c_feet: string (nullable = true)
#  |-- c_feet_color: string (nullable = true)
#  |-- c_fingernails: string (nullable = true)
#  |-- c_foot_width: string (nullable = true)
#  |-- c_forehead: string (nullable = true)
#  |-- c_forehead_shape: string (nullable = true)
#  |-- c_genitals: string (nullable = true)
#  |-- c_hair_appearance: string (nullable = true)
#  |-- c_hair_color: string (nullable = true)
#  |-- c_hair_covered: string (nullable = true)
#  |-- c_hair_curl: string (nullable = true)
#  |-- c_hair_length: string (nullable = true)
#  |-- c_hair_longer_on: string (nullable = true)
#  |-- c_hair_shorter_on: string (nullable = true)
#  |-- c_hair_thin: string (nullable = true)
#  |-- c_hair_tone: string (nullable = true)
#  |-- c_hands: string (nullable = true)
#  |-- c_hands_color: string (nullable = true)
#  |-- c_head_profile: string (nullable = true)
#  |-- c_head_size: string (nullable = true)
#  |-- c_heel: string (nullable = true)
#  |-- c_height: string (nullable = true)
#  |-- c_human_contact: string (nullable = true)
#  |-- c_human_hands: string (nullable = true)
#  |-- c_incident_ID: string (nullable = true)
#  |-- c_knees: string (nullable = true)
#  |-- c_leg_width: string (nullable = true)
#  |-- c_legs: string (nullable = true)
#  |-- c_lips: string (nullable = true)
#  |-- c_mouth_open: string (nullable = true)
#  |-- c_mouth_s: string (nullable = true)
#  |-- c_mouth_size: string (nullable = true)
#  |-- c_movement_direct: string (nullable = true)
#  |-- c_movement_first: string (nullable = true)
#  |-- c_movement_later: string (nullable = true)
#  |-- c_movement_was: string (nullable = true)
#  |-- c_neck_length: string (nullable = true)
#  |-- c_neck_width: string (nullable = true)
#  |-- c_no_hair: string (nullable = true)
#  |-- c_no_hair_on: string (nullable = true)
#  |-- c_nose: string (nullable = true)
#  |-- c_nose_shape: string (nullable = true)
#  |-- c_nostrils: string (nullable = true)
#  |-- c_object_handled: string (nullable = true)
#  |-- c_odour: string (nullable = true)
#  |-- c_operator: string (nullable = true)
#  |-- c_other_activity: string (nullable = true)
#  |-- c_other_color: string (nullable = true)
#  |-- c_other_unusual: string (nullable = true)
#  |-- c_pos_first_seen: string (nullable = true)
#  |-- c_posture: string (nullable = true)
#  |-- c_projecting_jaw: string (nullable = true)
#  |-- c_reaction: string (nullable = true)
#  |-- c_reflection: string (nullable = true)
#  |-- c_running_speed: string (nullable = true)
#  |-- c_running_steps: string (nullable = true)
#  |-- c_second_color: string (nullable = true)
#  |-- c_second_hair_color: string (nullable = true)
#  |-- c_shoulders: string (nullable = true)
#  |-- c_shoulders_shape: string (nullable = true)
#  |-- c_sound: string (nullable = true)
#  |-- c_speed: string (nullable = true)
#  |-- c_spine: string (nullable = true)
#  |-- c_state_prov: string (nullable = true)
#  |-- c_tail: string (nullable = true)
#  |-- c_teeth: string (nullable = true)
#  |-- c_then: string (nullable = true)
#  |-- c_then_creature: string (nullable = true)
#  |-- c_third_color: string (nullable = true)
#  |-- c_thumb: string (nullable = true)
#  |-- c_toe_shape: string (nullable = true)
#  |-- c_toenails: string (nullable = true)
#  |-- c_toenails_color: string (nullable = true)
#  |-- c_toes: string (nullable = true)
#  |-- c_torso_front: string (nullable = true)
#  |-- c_torso_shape: string (nullable = true)
#  |-- c_torso_side: string (nullable = true)
#  |-- c_use_of_water: string (nullable = true)
#  |-- c_walking_speed: string (nullable = true)
#  |-- c_walking_steps: string (nullable = true)
#  |-- c_water_activity: string (nullable = true)
#  |-- c_water_depth: string (nullable = true)
#  |-- c_way_of_walking: string (nullable = true)

# %%
# incidents_footprints = incidents_json.join(footprint_json, incidents_json.i_incident_id == footprint_json.f_incident_ID, 'inner')
print(footprint_json.columns)
incidents_footprints = incidents_json.join(footprint_json, incidents_json.i_incident_id == footprint_json.f_incident_ID, 'inner')
incidents_footprints_columns = ['i_incident_id', 'f_age_unit', 'f_animal_weight', 'f_arch', 'f_average', 'f_average_stride', 'f_ball', 'f_ball_of_foot', 'f_bumps', 'f_cast', 'f_claw_marks', 'f_comp_entry_date', 'f_condition', 'f_deformity', 'f_direction', 'f_estimated_age', 'f_feet_in_line', 'f_foot_shape', 'f_footprint_ID', 'f_greates_width', 'f_hand_print_s', 'f_heel', 'f_heel_width', 'f_human', 'f_human_tracks_present', 'f_incident_ID', 'f_knee_prints', 'f_length', 'f_longest_stride', 'f_longest_toe', 'f_material_made_in', 'f_number_of_toes', 'f_number_of_tracks', 'f_obs_print', 'f_obs_weight', 'f_obstacles', 'f_operation', 'f_other_footprint_codes', 'f_other_marks', 'f_other_tracks', 'f_pattern_of_walk', 'f_photo', 'f_remarks', 'f_ridge', 'f_set_of_tracks', 'f_shortest_stride', 'f_size_of_toes', 'f_state_prov', 'f_stride_inches', 'f_toes', 'f_trackmaker_attracted_by', 'f_tracks_came_from', 'f_tracks_showed', 'f_trail_ended', 'f_trail_followed', 'f_water', 'f_went_to', 'f_what']
incidents_footprints = incidents_footprints.select(incidents_footprints_columns).withColumnRenamed('i_incident_id', 'if_incident_id')
incidents_footprints.printSchema()
# Out:
# ['f_age_unit', 'f_animal_weight', 'f_arch', 'f_average', 'f_average_stride', 'f_ball', 'f_ball_of_foot', 'f_bumps', 'f_cast', 'f_claw_marks', 'f_comp_entry_date', 'f_condition', 'f_deformity', 'f_direction', 'f_estimated_age', 'f_feet_in_line', 'f_foot_shape', 'f_footprint_ID', 'f_greates_width', 'f_hand_print_s', 'f_heel', 'f_heel_width', 'f_human', 'f_human_tracks_present', 'f_incident_ID', 'f_knee_prints', 'f_length', 'f_longest_stride', 'f_longest_toe', 'f_material_made_in', 'f_number_of_toes', 'f_number_of_tracks', 'f_obs_print', 'f_obs_weight', 'f_obstacles', 'f_operation', 'f_other_footprint_codes', 'f_other_marks', 'f_other_tracks', 'f_pattern_of_walk', 'f_photo', 'f_remarks', 'f_ridge', 'f_set_of_tracks', 'f_shortest_stride', 'f_size_of_toes', 'f_state_prov', 'f_stride_inches', 'f_toes', 'f_trackmaker_attracted_by', 'f_tracks_came_from', 'f_tracks_showed', 'f_trail_ended', 'f_trail_followed', 'f_water', 'f_went_to', 'f_what']
# root
#  |-- if_incident_id: long (nullable = true)
#  |-- f_age_unit: string (nullable = true)
#  |-- f_animal_weight: long (nullable = true)
#  |-- f_arch: string (nullable = true)
#  |-- f_average: string (nullable = true)
#  |-- f_average_stride: string (nullable = true)
#  |-- f_ball: double (nullable = true)
#  |-- f_ball_of_foot: string (nullable = true)
#  |-- f_bumps: string (nullable = true)
#  |-- f_cast: string (nullable = true)
#  |-- f_claw_marks: string (nullable = true)
#  |-- f_comp_entry_date: string (nullable = true)
#  |-- f_condition: string (nullable = true)
#  |-- f_deformity: string (nullable = true)
#  |-- f_direction: string (nullable = true)
#  |-- f_estimated_age: string (nullable = true)
#  |-- f_feet_in_line: string (nullable = true)
#  |-- f_foot_shape: string (nullable = true)
#  |-- f_footprint_ID: long (nullable = true)
#  |-- f_greates_width: string (nullable = true)
#  |-- f_hand_print_s: string (nullable = true)
#  |-- f_heel: string (nullable = true)
#  |-- f_heel_width: string (nullable = true)
#  |-- f_human: string (nullable = true)
#  |-- f_human_tracks_present: string (nullable = true)
#  |-- f_incident_ID: string (nullable = true)
#  |-- f_knee_prints: string (nullable = true)
#  |-- f_length: string (nullable = true)
#  |-- f_longest_stride: long (nullable = true)
#  |-- f_longest_toe: string (nullable = true)
#  |-- f_material_made_in: string (nullable = true)
#  |-- f_number_of_toes: long (nullable = true)
#  |-- f_number_of_tracks: string (nullable = true)
#  |-- f_obs_print: double (nullable = true)
#  |-- f_obs_weight: long (nullable = true)
#  |-- f_obstacles: string (nullable = true)
#  |-- f_operation: string (nullable = true)
#  |-- f_other_footprint_codes: string (nullable = true)
#  |-- f_other_marks: string (nullable = true)
#  |-- f_other_tracks: string (nullable = true)
#  |-- f_pattern_of_walk: string (nullable = true)
#  |-- f_photo: string (nullable = true)
#  |-- f_remarks: string (nullable = true)
#  |-- f_ridge: string (nullable = true)
#  |-- f_set_of_tracks: long (nullable = true)
#  |-- f_shortest_stride: long (nullable = true)
#  |-- f_size_of_toes: string (nullable = true)
#  |-- f_state_prov: string (nullable = true)
#  |-- f_stride_inches: string (nullable = true)
#  |-- f_toes: double (nullable = true)
#  |-- f_trackmaker_attracted_by: string (nullable = true)
#  |-- f_tracks_came_from: string (nullable = true)
#  |-- f_tracks_showed: string (nullable = true)
#  |-- f_trail_ended: string (nullable = true)
#  |-- f_trail_followed: string (nullable = true)
#  |-- f_water: string (nullable = true)
#  |-- f_went_to: string (nullable = true)
#  |-- f_what: string (nullable = true)

# %%
incidents_all = incidents_json.join(incidents_creatures, incidents_json.i_incident_id == incidents_creatures.ic_incident_id, 'leftouter')
incidents_all = incidents_all.join(incidents_footprints, incidents_all.i_incident_id == incidents_footprints.if_incident_id, 'leftouter')
incidents_all = incidents_all.join(incidents_witnesses, incidents_all.i_incident_id == incidents_witnesses.iw_incident_id, 'leftouter')
incidents_all = incidents_all.dropDuplicates()
incidents_all.show()
# Out:
# +---------------------+-----------+---------+-----------+--------------------+-------------+------+------+---------------------+--------------------+-------------------+---------------+----------------+-----------+------------+---------------+-------------+-------------------+------------+--------------+----------+-------------+--------------------------+-----------------------+---------------+---------------+----------+-----------+-----------+-------+-------------------------+------------------+--------------------+-----------------+--------------+--------------+--------------------+-----------------+------------------+-----------------+----------+-------+------------+--------------------+---------------------+--------+----------+-------+-------------+------+----------------+-------------+--------------------+---------------+---------+------------+-------------+-------------------+---------------+----------------+--------------+-------+-----------------+-----------------+----------------+----------------+------------+------------+-----------+-----------------+----------+-------------+------------------+------------------+-----------------------+---------+------------------+--------------+---------+------+------------+-------------+-----------+--------------+-------------+---------------+----------------+----------+------+-------------+--------------------+----------+--------------+--------------+-------+---------+------------+------------+----------+----------+----------+------+--------------------+-------------------+-------------+------------+-------+-----------------+-----------------+-----------------+--------+----------+--------------------+--------+------------+-------------+-----------+----------+---------------+-----------+-----------+-----------+-------------+------+---------------+------------+-----------------+------+------------+-------------+------------+----------+----------------+----------+-----------------+------------+--------------+-----------+-------------+----------------+-----------------+-----------+-----------+-------+-------------+--------------+-----------+------+----------+---------------+-------------+-------------+-------+-----------+------+------+------------+---------+------------+-----------------+----------------+--------------------+--------------------+-------------+------------+------------------+------------+--------+------------+----------+----------------+-------+----------+----------------+-------------+---------------+----------------+----------------+----------------+------------------+--------------------+---------------+---------------+--------------+-------------------+-----------+-----------------+-------+-------+-------+------------+------+-------+--------------------+---------------+-------------+-------+-----------+----------+----------------+------+-------------+-------------+------------+--------------+---------------+---------------+----------------+-------------+----------------+--------------+----------+---------------+------+---------+----------------+------+--------------+-------+------+------------+-----------------+-----------+-----------+-----------+---------------+--------------+------------+--------------+---------------+--------------+------+------------+-------+----------------------+-------------+-------------+--------+----------------+-------------+------------------+----------------+------------------+-----------+------------+-----------+-----------+-----------------------+-------------+--------------+-----------------+-------+---------+-------+---------------+-----------------+--------------+------------+---------------+------+-------------------------+------------------+---------------+-------------+----------------+-------+---------+------+--------------+--------------------+------------+------------+-----------------+--------------+---------------+------------+-------------+-------+----------------+-------------+----------------------+---------------------+ ...
# |i_account_of_incident|i_cast_made|i_clarity|i_condition|            i_county|i_creature_id|i_dead|i_died|i_direction_from_town|i_distance_from_town|i_distance_to_water|     i_duration|i_effect_of_shot|i_elevation|i_entry_date|i_exact_terrain|i_exact_trees|i_exact_undergrowth|i_first_seen|i_footprint_id|i_humidity|i_incident_id|i_incident_one_of_a_series|i_incident_reliablility|i_incident_type|i_jwg_file_date|i_latitude| i_lighting|i_longitude|i_month|i_more_incident_codes_y_n|i_more_info_needed|              i_name|           i_near|i_nearby_water|i_nearest_town| i_no_of_individuals|i_no_of_witnesses|i_observation_date|i_observation_day|i_operator|i_photo|i_pop_status|i_population_of_town|i_related_incident_id|i_season|i_shot_hit|i_slope|i_slope_faced|i_snow|i_snow_condition|i_source_date|i_source_reliability|  i_source_type|i_species|i_state_prov| i_substratum|i_superhuman_action|      i_terrain|i_terrain_object| i_time_of_day|i_total|i_track_photo_y_n|i_track_witnesses|        i_tracks|i_tree_condition|i_tree_cover| i_tree_size|i_tree_type|i_trees_unnatural|    i_type|i_undergrowth|i_undergrowth_size|i_undergrowth_type|i_unnatural_undergrowth|i_variety|i_visibility_index|i_weather_heat|i_wetness|i_wind|i_witness_id|i_witness_sex|     i_year|ic_incident_id|    c_abdomen|c_aggressive_to|c_animal_present|c_arm_bulk|c_arms|c_arms_action|         c_arms_used|c_at_speed|c_attracted_by|c_back_of_head|c_beard|c_breasts|c_broken_ice|c_brow_ridge|   c_build|c_buttocks|c_captured|c_chin|   c_comp_entry_date|c_covered_with_hair|c_creature_ID|c_creature_c|c_death|c_decribe_unusual|c_detailed_report|c_different_color|c_digits|c_ear_size|              c_ears|c_eating|c_elim_where|c_elimination|c_est_speed|c_evidence|c_evidence_left|c_eye_color|c_eye_human|c_eye_shape|c_eye_spacing|c_eyes|c_face_appeared|c_face_color|c_face_expression|c_feet|c_feet_color|c_fingernails|c_foot_width|c_forehead|c_forehead_shape|c_genitals|c_hair_appearance|c_hair_color|c_hair_covered|c_hair_curl|c_hair_length|c_hair_longer_on|c_hair_shorter_on|c_hair_thin|c_hair_tone|c_hands|c_hands_color|c_head_profile|c_head_size|c_heel|  c_height|c_human_contact|c_human_hands|c_incident_ID|c_knees|c_leg_width|c_legs|c_lips|c_mouth_open|c_mouth_s|c_mouth_size|c_movement_direct|c_movement_first|    c_movement_later|      c_movement_was|c_neck_length|c_neck_width|         c_no_hair|c_no_hair_on|  c_nose|c_nose_shape|c_nostrils|c_object_handled|c_odour|c_operator|c_other_activity|c_other_color|c_other_unusual|c_pos_first_seen|       c_posture|c_projecting_jaw|        c_reaction|        c_reflection|c_running_speed|c_running_steps|c_second_color|c_second_hair_color|c_shoulders|c_shoulders_shape|c_sound|c_speed|c_spine|c_state_prov|c_tail|c_teeth|              c_then|c_then_creature|c_third_color|c_thumb|c_toe_shape|c_toenails|c_toenails_color|c_toes|c_torso_front|c_torso_shape|c_torso_side|c_use_of_water|c_walking_speed|c_walking_steps|c_water_activity|c_water_depth|c_way_of_walking|if_incident_id|f_age_unit|f_animal_weight|f_arch|f_average|f_average_stride|f_ball|f_ball_of_foot|f_bumps|f_cast|f_claw_marks|f_comp_entry_date|f_condition|f_deformity|f_direction|f_estimated_age|f_feet_in_line|f_foot_shape|f_footprint_ID|f_greates_width|f_hand_print_s|f_heel|f_heel_width|f_human|f_human_tracks_present|f_incident_ID|f_knee_prints|f_length|f_longest_stride|f_longest_toe|f_material_made_in|f_number_of_toes|f_number_of_tracks|f_obs_print|f_obs_weight|f_obstacles|f_operation|f_other_footprint_codes|f_other_marks|f_other_tracks|f_pattern_of_walk|f_photo|f_remarks|f_ridge|f_set_of_tracks|f_shortest_stride|f_size_of_toes|f_state_prov|f_stride_inches|f_toes|f_trackmaker_attracted_by|f_tracks_came_from|f_tracks_showed|f_trail_ended|f_trail_followed|f_water|f_went_to|f_what|iw_incident_id|   w_action_at_sight|w_approx_age|      w_city|w_comp_entry_date|w_confidential|w_date_of_birth|w_first_name|w_incident_id|w_index|w_interview_Date|w_interviewer|w_least_horiz_distance|w_least_vert_distance| ...
# +---------------------+-----------+---------+-----------+--------------------+-------------+------+------+---------------------+--------------------+-------------------+---------------+----------------+-----------+------------+---------------+-------------+-------------------+------------+--------------+----------+-------------+--------------------------+-----------------------+---------------+---------------+----------+-----------+-----------+-------+-------------------------+------------------+--------------------+-----------------+--------------+--------------+--------------------+-----------------+------------------+-----------------+----------+-------+------------+--------------------+---------------------+--------+----------+-------+-------------+------+----------------+-------------+--------------------+---------------+---------+------------+-------------+-------------------+---------------+----------------+--------------+-------+-----------------+-----------------+----------------+----------------+------------+------------+-----------+-----------------+----------+-------------+------------------+------------------+-----------------------+---------+------------------+--------------+---------+------+------------+-------------+-----------+--------------+-------------+---------------+----------------+----------+------+-------------+--------------------+----------+--------------+--------------+-------+---------+------------+------------+----------+----------+----------+------+--------------------+-------------------+-------------+------------+-------+-----------------+-----------------+-----------------+--------+----------+--------------------+--------+------------+-------------+-----------+----------+---------------+-----------+-----------+-----------+-------------+------+---------------+------------+-----------------+------+------------+-------------+------------+----------+----------------+----------+-----------------+------------+--------------+-----------+-------------+----------------+-----------------+-----------+-----------+-------+-------------+--------------+-----------+------+----------+---------------+-------------+-------------+-------+-----------+------+------+------------+---------+------------+-----------------+----------------+--------------------+--------------------+-------------+------------+------------------+------------+--------+------------+----------+----------------+-------+----------+----------------+-------------+---------------+----------------+----------------+----------------+------------------+--------------------+---------------+---------------+--------------+-------------------+-----------+-----------------+-------+-------+-------+------------+------+-------+--------------------+---------------+-------------+-------+-----------+----------+----------------+------+-------------+-------------+------------+--------------+---------------+---------------+----------------+-------------+----------------+--------------+----------+---------------+------+---------+----------------+------+--------------+-------+------+------------+-----------------+-----------+-----------+-----------+---------------+--------------+------------+--------------+---------------+--------------+------+------------+-------+----------------------+-------------+-------------+--------+----------------+-------------+------------------+----------------+------------------+-----------+------------+-----------+-----------+-----------------------+-------------+--------------+-----------------+-------+---------+-------+---------------+-----------------+--------------+------------+---------------+------+-------------------------+------------------+---------------+-------------+----------------+-------+---------+------+--------------+--------------------+------------+------------+-----------------+--------------+---------------+------------+-------------+-------+----------------+-------------+----------------------+---------------------+ ...
# |                     |           |         |           |       Clackamas Cty|             |      |      |                     |                null|                   |               |                |       null|            |               |             |                   |            |              |          |           26|                          |                   null|               |               |      4518|           |      12221|    Jun|                         |                  |File card says na...|            shore|          lake|      Estacada|one large, sex un...|                4|       JUN 15 1964|                 |          |       |            |                null|                     |  summer|          |       |             |      |                |             |                null|               |         |      Oregon|             |                   |          shore|                |              |      1|                 |                 |                |                |            |            |           |                 |          |             |                  |                  |                       |         |              null|              |         |      |            |            M|       1964|            26|             |               |                |          |      |             |                    |          |              |              |       |         |            |            |          |          |          |      |                    |                   |           26|            |       |                 |                 |                 |        |          |                    |        |            |             |           |          |               |           |           |           |             |      |               |            |                 |      |            |             |            |          |                |          |                 |            |              |           |             |                |                 |           |           |       |             |              |           |      |          |               |             |           26|       |           |      |      |            |         |            |                 |                |                fled|                    |             |            |                  |            |        |            |          |                |       |          |                |             |               |                |                |                |                  |                    |               |               |              |                   |           |                 |       |       |       |            |      |       |                    |               |             |       |           |          |                |      |             |             |            |              |               |               |                |             |                |            26|          |           null|      |         |                |  null|              |       |      |            |                 |           |           |           |               |              |            |            26|               |              |      |            |       |                      |           26|             |        |            null|             |                  |            null|                  |       null|        null|           |           |                       |             |              |                 |       |         |       |           null|             null|              |            |               |  null|                         |                  |               |             |                |       |         |      |            26|            harassed|            |            |                 |              |               |            |           26|       |                |             |                      |                     | ...
# |                     |           |         |           |           Wasco Cty|             |      |      |                     |                null|                   |          brief|                |       null|            |               |             |                   |            |              |          |           29|                          |                   null|               |               |      4537|           |      12120|       |                         |                  |Dalene Brown, 811...|             camp|         river|    The Dalles|one large, sex un...|                2|                  |                 |          |       |       rural|                null|                     |  summer|          |       |             |      |                |             |                null|               |         |      Oregon|             |                   |         valley|                |         night|      1|                 |                 |     found later|                |            |            |           |                 |          |             |                  |                  |                       |         |              null|              |         |      |            |            F|       1968|            29|             |               |                |          |      |             |                    |          |human activity|              |       |         |            |            |          |          |          |      |                    |                   |           29|            |       |                 |                 |                 |        |          |                    |        |            |             |           |          |     footprints|           |           |           |             |      |               |            |                 |      |            |             |            |          |                |          |                 |            |      presumed|           |             |                |                 |           |           |       |             |              |           |      |          |          watch|             |           29|       |           |      |      |            |         |            |                 |   staying still|                fled|                    |             |            |                  |            |        |            |          |                |       |          |                |             |               |       squatting|           erect|                | watched;fled from|                    |               |               |              |                   |           |                 |       |       |       |            |      |       |                    |               |             |       |           |          |                |      |             |             |            |              |               |               |                |             |                |            29|          |           null|      |         |                |  null|              |       |      |            |                 |           |           |           |               |              |            |            29|               |              |      |            |       |                      |           29|             |        |            null|             |                  |            null|                  |       null|        null|           |           |                       |             |              |                 |       |         |       |              1|             null|              |            |               |  null|                         |                  |               |             |                |       |         |      |            29|             shouted|            |            |                 |              |               |            |           29|       |                |             |                      |                     | ...
# |                     |           |         |           |       Snohomish Cty|             |      |      |                     |                null|                   |          brief|                |       null|            |               |             |                   |          on|              |          |          474|                         Y|                   null|               |               |      4815|   daylight|      12200|       |                         |                  |BFRO from Wendel ...|            water|         creek|        Cicero| one, no description|                1|                  |                 |          |       |       rural|                null|                     |        |          |       |             |      |                |             |                null|               |         |        Wash|             |                   |       foothill|            road|           day|      1|                 |                 |                |                |            |            |           |                 |          |             |                  |                  |                       |         |              null|              |         |      |            |             | about 1958|           474|             |               |                |          |      |             |                    |          |              |              |       |         |            |            |          |          |          |      |                    |                   |          474|            |       |                 |                 |                 |        |          |                    |        |            |             |           |          |               |           |           |           |             |      |               |            |                 |      |            |             |            |          |                |          |                 |            |              |           |             |                |                 |           |           |       |             |              |           |      |          |               |             |          474|       |           |      |      |            |         |            |                 |                |        crossed road|                    |             |            |                  |            |        |            |          |                |       |          |                |             |               |                |                |                |                  |                    |               |               |              |                   |           |                 |       |       |       |            |      |       |                    |               |             |       |           |          |                |      |             |             |            |              |               |               |                |             |                |           474|          |           null|      |         |                |  null|              |       |      |            |                 |           |           |           |               |              |            |           474|               |              |      |            |       |                      |          474|             |        |            null|             |                  |            null|                  |       null|        null|           |           |                       |             |              |                 |       |         |       |           null|             null|              |            |               |  null|                         |                  |               |             |                |       |         |      |           474|                    |            |            |                 |              |               |            |          474|       |                |             |                      |                     | ...
# | Five teenagers dr...|           |         |           |        Lawrence Cty|             |      |      |                     |                null|                   |   considerable|                |       null|            |               |             |                   |          on|              |          |       991010|                          |                   null|               |               |      3844| headlights|       8741|       |                         |                  |Lawrenceville, IL...|                 |          pond| Lawrenceville|one large, sex un...|                5|                  |                 |          |       |        wild|                null|                     |  summer|          |       |             |      |                |             |                null|               |         |    Illinois|             |                   |               |            road|         night|      1|                 |                 |                |                |            |            |           |                 |          |             |                  |                  |                       |         |              null|              |         |      |            |            B| about 1953|        991010|             |               |                |          |  long|             |                    |          |              |              |       |         |            |            |      thin|          |          |      |                    |                   |       991010|            |       |                 |                 |                 |        |          |                    |        |            |             |           |          |               |           |           |           |             |      |               |            |                 |      |            |             |            |          |                |          |                 |  grey brown|           yes|           |             |                |                 |           |           |       |             |              |           |      |    7-8 ft|               |             |       991010|       |           |      |      |            |         |            |                 |         walking|stopped stillýwat...|across observer f...|             |            |                  |            |        |            |          |                |       |          |                |             |               |           erect|           erect|                |                  |                    |               |               |              |                   |           |                 |       |       |       |            |      |       |crossed roadýfled...|               |             |       |           |          |                |      |             |             |            |              |               |               |                |             |                |        991010|          |           null|      |         |                |  null|              |       |      |            |                 |           |           |           |               |              |            |        991010|               |              |      |            |       |                      |       991010|             |        |            null|             |                  |            null|                  |       null|        null|           |           |                       |             |              |                 |       |         |       |           null|             null|              |            |               |  null|                         |                  |               |             |                |       |         |      |        991010|stayed stillýstudied|            |            |                 |              |               |            |       991010|       |                |             |               25 feet|                     | ...
# | Darrel Bulzomi, p...|           |         |           |Lake of the Woods...|             |      |      |                     |                null|                   |               |                |       null|            |               |             |                   |          on|              |          |       991229|                          |                   null|               |               |      4845|           |       9450|       |                         |                  |The Sasquatch in ...|                 |              |      Graceton|one large, sex un...|                1|                  |                 |          |       |            |                null|                     |        |          |       |             |      |                |             |                null|               |         |        Minn|             |                   |               |            road|              |      1|                 |                 |                |                |            |            |           |                 |          |             |                  |                  |                       |         |              null|              |         |      |            |            M|       1978|        991229|             |               |                |          |      |             |                    |          |              |              |       |         |            |            |     heavy|          |          |      |                    |                   |       991229|            |       |                 |                 |                 |        |          |                    |        |            |             |           |          |               |           |           |           |             |      |               |            |                 |      |            |             |            |          |                |          |                 |            |              |           |             |                |                 |           |           |       |             |              |           |      |     large|               |             |       991229|       |           |      |      |            |         |            |                 |                |        crossed road|                    |             |            |                  |            |        |            |          |                |       |          |                |             |               |           erect|           erect|                |                  |                    |               |               |              |                   |           |                 |       |       |       |            |      |       |                    |               |             |       |           |          |                |      |             |             |            |              |               |               |                |             |                |        991229|          |           null|      |         |                |  null|              |       |      |            |                 |           |           |           |               |              |            |        991229|               |              |      |            |       |                      |       991229|             |        |            null|             |                  |            null|                  |       null|        null|           |           |                       |             |              |                 |       |         |       |           null|             null|              |            |               |  null|                         |                  |               |             |                |       |         |      |        991229|                    |            |            |                 |              |               |            |       991229|       |                |             |                      |                     | ...
# | William Schwark a...|           |         |           |        Cuyahoga Cty|             |      |      |                     |                null|                   |   considerable|                |       null|            |               |             |                   |          in|              |          |       991290|                          |                   null|               |               |      4130|           |       8140|    Apr|                         |                  |Cleveland Plain D...|                 |              |     Cleveland|one large, sex un...|                2|       APR 22 1968|                 |          |       |       urban|                null|                     |  spring|          |       |             |      |                |             |                null|               |         |        Ohio|             |                   |          woods|           trees|         night|      1|                 |                 |                |                |            |            |           |                 |          |             |                  |                  |                       |         |              null|              |         |      |            |            M|       1968|        991290|             |          youth|                |          |      |             |hanging onto some...|          |              |              |       |         |            |            |          |          |          |      |                    |                   |       991290|            |       |                 |                 |                 |        |          |                    |        |            |             |           |          |               |           |           |           |             |      |               |            |                 |      |            |             |            |          |                |          |                 |       black|           yes|           |             |                |                 |           |           |       |             |              |           |      |      8 ft|          touch|             |       991290|       |           |      |      |            |         |            |                 |                |   handled something|                    |             |            |                  |            |        |            |          |          person|       |          |                |             |               |           erect|           erect|                |                  |                    |               |               |              |                   |           |                 |       |       |       |            |      |       |                    |               |             |       |           |          |                |      |             |             |            |              |               |               |                |             |                |        991290|          |           null|      |         |                |  null|              |       |      |            |                 |           |           |           |               |              |            |        991290|               |              |      |            |       |                      |       991290|             |        |            null|             |                  |            null|                  |       null|        null|           |           |                       |             |              |                 |       |         |       |           null|             null|              |            |               |  null|                         |                  |               |             |                |       |         |      |        991290|              chased|            |            |                 |              |               |            |       991290|       |                |             |               contact|                     | ...
# | Several sightings...|           |         |           |         Portage Cty|             |      |      |                     |                null|                   |               |                |       null|            |               |             |                   |            |              |          |       991415|                         Y|                   null|               |               |      4101|           |       8103|    Oct|                         |                  |Matt Moneymaker, ...|                 |          lake|     Deerfield| one, no description|                 |                  |                 |          |       |            |                null|                     |    fall|          |       |             |      |                |             |                null|               |         |        Ohio|             |                   |               |                |              |       |                 |                 |                |                |            |            |           |                 |          |             |                  |                  |                       |         |              null|              |         |      |            |             |       1993|        991415|             |               |                |          |      |             |                    |          |              |              |       |         |            |            |          |          |          |      |                    |                   |       991415|            |       |                 |                 |                 |        |          |                    |        |            |             |           |          |               |           |           |           |             |      |               |            |                 |      |            |             |            |          |                |          |                 |            |              |           |             |                |                 |           |           |       |             |              |           |      |          |               |             |       991415|       |           |      |      |            |         |            |                 |                |                    |                    |             |            |                  |            |        |            |          |                |       |          |                |             |               |                |                |                |                  |                    |               |               |              |                   |           |                 |       |       |       |            |      |       |                    |               |             |       |           |          |                |      |             |             |            |              |               |               |                |             |                |        991415|          |           null|      |         |                |  null|              |       |      |            |                 |           |           |           |               |              |            |        991415|               |              |      |            |       |                      |       991415|             |        |            null|             |                  |            null|                  |       null|        null|           |           |                       |             |              |                 |       |         |       |           null|             null|              |            |               |  null|                         |                  |               |             |                |       |         |      |        991415|                    |            |            |                 |              |               |            |       991415|       |                |             |                      |                     | ...
# | Joe Atwood says t...|           |         |           |       McCurtain Cty|             |      |      |                     |                null|                   |          brief|                |       null|            |               |             |                   |            |              |          |       991477|                          |                   null|               |               |      3354| flashlight|       9450|       |                         |                  |Tulsa, OK, Tribun...|                 |              |        Idabel|one large, sex un...|                1|                  |                 |          |       |        wild|                null|                     |  spring|          |       |             |      |                |             |                null|               |         |    Oklahoma|             |                   |          woods|                |         night|      1|                 |                 |       not found|                |            |            |           |                 |          |             |                  |                  |                       |         |              null|              |         |      |            |            M|       1989|        991477|             |               |                |          |      |             |                    |          |              |              |       |         |            |            |     heavy|          |          |      |                    |                   |       991477|            |       |                 |                 |                 |        |          |                    |        |            |             |           |          |               |           |           |           |             |      |               |            |                 |      |            |             |            |          |                |          |                 |        dark|      presumed|           |             |                |                 |           |           |       |             |              |           |      |    7-8 ft|               |             |       991477|       |           |      |      |            |         |            |                 |         running|                    |  away from observer|             |            |                  |            |        |            |          |                | strong|          |                |             |               |           erect|           erect|                |         fled from|lighted but did n...|               |               |              |                   |           |                 | scream|       |       |            |      |       |                    |               |             |       |           |          |                |      |             |             |            |              |               |               |                |             |                |        991477|          |           null|      |         |                |  null|              |       |      |            |                 |           |           |           |               |              |            |        991477|               |              |      |            |       |                      |       991477|             |        |            null|             |                  |            null|                  |       null|        null|           |           |                       |             |              |                 |       |         |       |           null|             null|              |            |               |  null|                         |                  |               |             |                |       |         |      |        991477|                    |            |            |                 |              |               |            |       991477|       |                |             |              50 yards|                     | ...
# ...
# | Couple sitting at...|           | overcast|           |  Bulkley Valley Dis|         1052|      |      |                South|                 4.0|                   |         minute|                |       15.0| JAN 09 1993|       clearing|         none|               none|          in|         10021|          |      1000061|                          |                      6|              3|               |    54573-|heavy cloud|    127200-|       |                         |                  |name forgotten, 1...|             road|              |    Moricetown|one large, sex un...|                 |                  |                 |       JWG|       |       rural|                 100|                     |        |         N|  level|             |      |                |         1970|                   7|computer survey|         |     Br. Col|forest litter|                   |           hill|         pasture| early morning|      1|                 |                 |     found later|   mostly mature|       heavy|mostly large| coniferous|                 |1st person|         none|                  |                  |                       |         |                 7|              |         |      |      100065|            B|       1961|          null|         null|           null|            null|      null|  null|         null|                null|      null|          null|          null|   null|     null|        null|        null|      null|      null|      null|  null|                null|               null|         null|        null|   null|             null|             null|             null|    null|      null|                null|    null|        null|         null|       null|      null|           null|       null|       null|       null|         null|  null|           null|        null|             null|  null|        null|         null|        null|      null|            null|      null|             null|        null|          null|       null|         null|            null|             null|       null|       null|   null|         null|          null|       null|  null|      null|           null|         null|         null|   null|       null|  null|  null|        null|     null|        null|             null|            null|                null|                null|         null|        null|              null|        null|    null|        null|      null|            null|   null|      null|            null|         null|           null|            null|            null|            null|              null|                null|           null|           null|          null|               null|       null|             null|   null|   null|   null|        null|  null|   null|                null|           null|         null|   null|       null|      null|            null|  null|         null|         null|        null|          null|           null|           null|            null|         null|            null|       1000061|     hours|           null|     N|     4.50|              48|  null|              |       |      |            |      JAN 09 1993|  very good|           |           |              2|              |            |         10021|               |              |      |            |       |                      |      1000061|             |    16.0|            null|             |               sod|               5|               200|        0.5|        null|           |        JWG|                       |             |              |                 |       |         |       |              1|             null|              |     Br. Col|               |  null|                         |                  |               |            Y|               Y|       |         |      |          null|                null|        null|        null|             null|          null|           null|        null|         null|   null|            null|         null|                  null|                 null| ...
# | Bob Titmus found ...|           |         |           |       Hawksbury Isl|             |      |      |      South Southwest|                33.0|            10 feet|               |                |       10.0| JAN 09 1993|         stream|         none|               none|          on|         10025|       low|      1000070|                          |                      5|              2|               |    53361-|           |    128233-|    Aug|                         |                  |Bob Titmus intv. ...|            water|         creek|       Kitimat|one large, sex un...|                 |                  |                 |       JWG|       |        wild|                8000|                     |  summer|         N|  level|             |      |                |         1970|                   9|computer survey|         |     Br. Col|fine material|                   |   ocean;island|           shore|              |      1|                 |                 |                |                |       heavy|mostly small|           |                 |1st person|        heavy|              high|                  |                       |         |              null|        normal|   normal|      |      100074|             |       1962|          null|         null|           null|            null|      null|  null|         null|                null|      null|          null|          null|   null|     null|        null|        null|      null|      null|      null|  null|                null|               null|         null|        null|   null|             null|             null|             null|    null|      null|                null|    null|        null|         null|       null|      null|           null|       null|       null|       null|         null|  null|           null|        null|             null|  null|        null|         null|        null|      null|            null|      null|             null|        null|          null|       null|         null|            null|             null|       null|       null|   null|         null|          null|       null|  null|      null|           null|         null|         null|   null|       null|  null|  null|        null|     null|        null|             null|            null|                null|                null|         null|        null|              null|        null|    null|        null|      null|            null|   null|      null|            null|         null|           null|            null|            null|            null|              null|                null|           null|           null|          null|               null|       null|             null|   null|   null|   null|        null|  null|   null|                null|           null|         null|   null|       null|      null|            null|  null|         null|         null|        null|          null|           null|           null|            null|         null|            null|       1000070|     hours|           null|      |     2.00|              42|  null|              |       |      |            |      JAN 09 1993|       fair|           |  Southwest|             12|              |            |         10025|            7.0|              |      |         3.0|       |                      |      1000070|             |    14.0|            null|             |          dry sand|               5|                 3|       0.75|         160|           |        JWG|                       |             |              |                 |       |         |       |              1|             null|              |     Br. Col|               |  null|                         |                  |               |            Y|                |       |         |      |       1000070|                    |    41 to 50|New Hazelton|      JAN 09 1993|             N|               |         Bob|      1000070|       |       JULY 1970|   John Green|                      |                     | ...
# +---------------------+-----------+---------+-----------+--------------------+-------------+------+------+---------------------+--------------------+-------------------+---------------+----------------+-----------+------------+---------------+-------------+-------------------+------------+--------------+----------+-------------+--------------------------+-----------------------+---------------+---------------+----------+-----------+-----------+-------+-------------------------+------------------+--------------------+-----------------+--------------+--------------+--------------------+-----------------+------------------+-----------------+----------+-------+------------+--------------------+---------------------+--------+----------+-------+-------------+------+----------------+-------------+--------------------+---------------+---------+------------+-------------+-------------------+---------------+----------------+--------------+-------+-----------------+-----------------+----------------+----------------+------------+------------+-----------+-----------------+----------+-------------+------------------+------------------+-----------------------+---------+------------------+--------------+---------+------+------------+-------------+-----------+--------------+-------------+---------------+----------------+----------+------+-------------+--------------------+----------+--------------+--------------+-------+---------+------------+------------+----------+----------+----------+------+--------------------+-------------------+-------------+------------+-------+-----------------+-----------------+-----------------+--------+----------+--------------------+--------+------------+-------------+-----------+----------+---------------+-----------+-----------+-----------+-------------+------+---------------+------------+-----------------+------+------------+-------------+------------+----------+----------------+----------+-----------------+------------+--------------+-----------+-------------+----------------+-----------------+-----------+-----------+-------+-------------+--------------+-----------+------+----------+---------------+-------------+-------------+-------+-----------+------+------+------------+---------+------------+-----------------+----------------+--------------------+--------------------+-------------+------------+------------------+------------+--------+------------+----------+----------------+-------+----------+----------------+-------------+---------------+----------------+----------------+----------------+------------------+--------------------+---------------+---------------+--------------+-------------------+-----------+-----------------+-------+-------+-------+------------+------+-------+--------------------+---------------+-------------+-------+-----------+----------+----------------+------+-------------+-------------+------------+--------------+---------------+---------------+----------------+-------------+----------------+--------------+----------+---------------+------+---------+----------------+------+--------------+-------+------+------------+-----------------+-----------+-----------+-----------+---------------+--------------+------------+--------------+---------------+--------------+------+------------+-------+----------------------+-------------+-------------+--------+----------------+-------------+------------------+----------------+------------------+-----------+------------+-----------+-----------+-----------------------+-------------+--------------+-----------------+-------+---------+-------+---------------+-----------------+--------------+------------+---------------+------+-------------------------+------------------+---------------+-------------+----------------+-------+---------+------+--------------+--------------------+------------+------------+-----------------+--------------+---------------+------------+-------------+-------+----------------+-------------+----------------------+---------------------+ ...
# only showing top 20 rows
